# %% [markdown]
# # Exercise 2.3 Fundamentals of visualization libraries part 1 B Matplotlib

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime as dt

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.9.2'

# %%
df = pd.read_csv('NewYork_data.csv', index_col = 0)
# Out:
# C:\Users\tjsra\AppData\Local\Temp\ipykernel_12016\3432159168.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('NewYork_data.csv', index_col = 0)

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp', '_merge'],
#       dtype='object')

# %%
df.drop(columns = {'_merge'}, inplace = True)

# %%
df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  344EB2CD04CD1B71   classic_bike  2022-04-13 18:46:17.884
# 1  17248543C251F4FB  electric_bike  2022-06-24 16:08:25.267
# 2  43658D9AB9938656   classic_bike  2022-05-28 18:39:18.883
# 3  0158721C43867EFE   classic_bike  2022-04-29 19:33:55.052
# 4  B08E1E3FFC1F965B   classic_bike  2022-09-30 09:43:40.072
#
#                   ended_at             start_station_name start_station_id  \
# 0  2022-04-13 18:54:21.655       Lafayette St & Jersey St          5561.06
# 1  2022-06-24 16:23:26.771                W 29 St & 9 Ave          6416.06
# 2  2022-05-28 19:09:58.450             N 11 St & Kent Ave          5489.04
# 3  2022-04-29 19:40:16.920        DeKalb Ave & Hudson Ave          4513.06
# 4  2022-09-30 09:58:17.811  Christopher St & Greenwich St          5847.01
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0                W 15 St & 6 Ave        5989.02  40.724561 -73.995653
# 1          Spring St & Hudson St        5653.12  40.750073 -73.998393
# 2              Kent Ave & N 7 St        5489.03  40.722482 -73.959219
# 3  Flushing Ave & Vanderbilt Ave        4762.05  40.689888 -73.981013
# 4          7 Ave S & Bleecker St        5805.07  40.732916 -74.007114
#
#      end_lat    end_lng member_casual        date  avgTemp
# 0  40.738046 -73.996430        member  2022-04-13     15.4
# 1  40.725840 -74.007653        casual  2022-06-24     21.9
# 2  40.720368 -73.961651        casual  2022-05-28     20.4
# 3  40.697950 -73.970776        casual  2022-04-29     10.4
# 4  40.732139 -74.003638        member  2022-09-30     14.5

# %%
df.shape
# Out:
# (801824, 15)

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# date                   object
# avgTemp               float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at                    object
# ended_at                      object
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# date                  datetime64[ns]
# avgTemp                      float64
# dtype: object

# %%
df_temp = df.set_index('date')

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type               started_at  \
# date
# 2022-04-13  344EB2CD04CD1B71   classic_bike  2022-04-13 18:46:17.884
# 2022-06-24  17248543C251F4FB  electric_bike  2022-06-24 16:08:25.267
# 2022-05-28  43658D9AB9938656   classic_bike  2022-05-28 18:39:18.883
# 2022-04-29  0158721C43867EFE   classic_bike  2022-04-29 19:33:55.052
# 2022-09-30  B08E1E3FFC1F965B   classic_bike  2022-09-30 09:43:40.072
#
#                            ended_at             start_station_name  \
# date
# 2022-04-13  2022-04-13 18:54:21.655       Lafayette St & Jersey St
# 2022-06-24  2022-06-24 16:23:26.771                W 29 St & 9 Ave
# 2022-05-28  2022-05-28 19:09:58.450             N 11 St & Kent Ave
# 2022-04-29  2022-04-29 19:40:16.920        DeKalb Ave & Hudson Ave
# 2022-09-30  2022-09-30 09:58:17.811  Christopher St & Greenwich St
#
#            start_station_id               end_station_name end_station_id  \
# date
# 2022-04-13          5561.06                W 15 St & 6 Ave        5989.02
# 2022-06-24          6416.06          Spring St & Hudson St        5653.12
# 2022-05-28          5489.04              Kent Ave & N 7 St        5489.03
# 2022-04-29          4513.06  Flushing Ave & Vanderbilt Ave        4762.05
# 2022-09-30          5847.01          7 Ave S & Bleecker St        5805.07
#
#             start_lat  start_lng    end_lat    end_lng member_casual  avgTemp
# date
# 2022-04-13  40.724561 -73.995653  40.738046 -73.996430        member     15.4
# 2022-06-24  40.750073 -73.998393  40.725840 -74.007653        casual     21.9
# 2022-05-28  40.722482 -73.959219  40.720368 -73.961651        casual     20.4
# 2022-04-29  40.689888 -73.981013  40.697950 -73.970776        casual     10.4
# 2022-09-30  40.732916 -74.007114  40.732139 -74.003638        member     14.5

# %%
df_temp = df_temp.sort_values(by='date')

# %%
df_grouped = df_temp.groupby('date').agg({'avgTemp': 'mean'})

# %%
df_grouped['avgTemp'].plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# # procedural Approach

# %%
plt.plot(df_temp['avgTemp'])
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.title('Temperatures daily for 2022')
plt.plot(df_temp['avgTemp'])
plt.show()

# %% [markdown]
# # Aggregate Trips

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp'],
#       dtype='object')

# %%
# Groupby the count of the trips 
df_group = pd.DataFrame(df.groupby(['date'])['ride_id'].count()).reset_index()

# %%
df_group.head()
# Out:
#         date  ride_id
# 0 2022-01-01      565
# 1 2022-01-02     1130
# 2 2022-01-03      940
# 3 2022-01-04     1000
# 4 2022-01-05      922

# %%
df_group.rename(columns = {'ride_id':'bike_rides_daily'}, inplace = True)
df = df.merge(df_group, on = "date", how = 'outer', indicator = True)
print(df['_merge'].value_counts(dropna = False))
print("Shape of January 1st is", df[df['date'] == '2022-01-01'].shape) # Check 
print("Shape of January 2nd is", df[df['date'] == '2022-01-02'].shape) # Second check 

df_temp = df.set_index('date')

print(df_temp.columns)
# Out:
# _merge
# both          801824
# left_only          0
# right_only         0
# Name: count, dtype: int64
# Shape of January 1st is (565, 17)
# Shape of January 2nd is (1130, 17)
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'avgTemp', 'bike_rides_daily', '_merge'],
#       dtype='object')

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type               started_at  \
# date
# 2022-01-01  69198402DE2F09D9  electric_bike  2022-01-01 18:47:29.261
# 2022-01-01  A88286580E006A23   classic_bike  2022-01-01 12:11:43.270
# 2022-01-01  5C8D80FADFCE6A5A   classic_bike  2022-01-01 12:39:49.213
# 2022-01-01  EE8147050ACEB21C   classic_bike  2022-01-01 10:44:01.137
# 2022-01-01  21B74269FD2FCDBD   classic_bike  2022-01-01 01:11:09.098
#
#                            ended_at       start_station_name start_station_id  \
# date
# 2022-01-01  2022-01-01 19:34:01.835      Mott St & Prince St          5561.04
# 2022-01-01  2022-01-01 12:22:41.986  Dock 72 Way & Market St          4804.02
# 2022-01-01  2022-01-01 12:45:54.864           Great Jones St          5636.11
# 2022-01-01  2022-01-01 10:46:53.936          E 13 St & 2 Ave          5820.08
# 2022-01-01  2022-01-01 01:36:58.774          W 17 St & 8 Ave          6148.02
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# date
# 2022-01-01       E 138 St & Cypress Ave        7669.10  40.723180 -73.994800
# 2022-01-01  Washington Ave & Greene Ave        4419.03  40.699850 -73.971410
# 2022-01-01              W 13 St & 7 Ave        6030.04  40.727434 -73.993790
# 2022-01-01     Cooper Square & Astor Pl        5712.03  40.731539 -73.985302
# 2022-01-01         Duane St & Hudson St        5359.12  40.741776 -74.001497
#
#               end_lat    end_lng member_casual  avgTemp  bike_rides_daily  \
# date
# 2022-01-01  40.805559 -73.914718        member     11.6               565
# 2022-01-01  40.686501 -73.965633        member     11.6               565
# 2022-01-01  40.737815 -73.999947        casual     11.6               565
# 2022-01-01  40.729515 -73.990753        member     11.6               565
# 2022-01-01  40.717030 -74.009250        casual     11.6               565
#
#            _merge
# date
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both

# %%
plt.figure(figsize=(10,5))
plt.title('Temperature per trips')
plt.plot(df_temp['avgTemp'])
plt.plot(df_temp['bike_rides_daily'], color = 'red')
plt.show()

# %% [markdown]
# # Object-Oriented Approach

# %%
# Create figure and axis objects with subplots()

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "red")
ax.plot(df_temp['avgTemp'], color = 'blue')

# %%
# Create figure and axis objects with subplots()

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "red")

# Here is where we create the dual axis - initialize a twin object for two different y-axis on the sample plot
ax2 = ax.twinx()

# Make a plot with the temperatues on the y-axis using second axis object
ax2.plot(df_temp["avgTemp"], color = "blue")
plt.show()

# %% [markdown]
# # Final Dual Plot

# %%
# Create figure and axis objects with subplots() and details

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "navy")
ax.set_xlabel("Year 2022", fontsize = 14) # set x-axis label
ax.set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

# Here is where we create the dual axis - initialize a twin object for two different y-axis on the sample plot
ax2 = ax.twinx()

# Make a plot with the temperatues on the y-axis using second axis object
ax2.plot(df_temp["avgTemp"], color = "red")
ax2.set_ylabel("Average temperatures", color = "red",fontsize=14)
plt.title('Temperature and trips in 2022', fontsize = 18)
plt.show()

# %%
plt.style.use('ggplot')

# %%
# Create figure and axis objects with subplots() and details

fig,ax = plt.subplots(2, figsize =(8, 6))

# Make a plot of the bike rides
ax[0].plot(df_temp['bike_rides_daily'],color = "navy")
ax[0].set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

# Make a plot with the temperatues on the y-axis using second axis object
ax[1].plot(df_temp["avgTemp"], color = "red")
ax[1].set_ylabel("Average temperatures", color = "red",fontsize=14)
plt.suptitle('Temperature and trips in 2022', fontsize = 18)

plt.show()

# %%
# save the plot as a file
fig.savefig('trips_temperatures_dual_line.jpg',
              format='jpeg',
              dpi=100,
              bbox_inches='tight')
